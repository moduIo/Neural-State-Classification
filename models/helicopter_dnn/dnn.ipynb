# %%
import pandas as pd
# %matplotlib inline

# %% [markdown]
# # Data Exploration

# %%
data = pd.read_csv('../../datasets/heli_uniform/heli_1m_uniform.csv')

# %%
data.hist(grid=False, figsize=(15,40), layout=(10,3), bins=100, sharex=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12c027dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12022f5d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123cde8d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1252a9e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112df6d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12affc7d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12b1f8710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12b79da10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12bb9f490>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12c009b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12c8629d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12c8a8750>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12c8c4210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12c92b810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12c962210>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12c99dbd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12c9e6450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12ca20c10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12ca51690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12caa0390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12cad9fd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12caf7c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12cb690d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12cb92c10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12cbba650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12cc17e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12cc5f5d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12cc7c550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12ccd1d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12cd17a10>]],
#       dtype=object)
